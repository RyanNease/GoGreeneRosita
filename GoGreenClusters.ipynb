# %%
# !pip install astropy
# !pip install numpy
# !pip install matplotlib
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
# Out:
# Requirement already satisfied: astropy in c:\users\nease\anaconda3\lib\site-packages (5.3.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\nease\anaconda3\lib\site-packages (from astropy) (1.26.4)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\nease\anaconda3\lib\site-packages (from astropy) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\nease\anaconda3\lib\site-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\nease\anaconda3\lib\site-packages (from astropy) (23.1)
# Requirement already satisfied: numpy in c:\users\nease\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\nease\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nease\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nease\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
fits_file_path = 'Clusters.fits'
# Open the FITS file

with fits.open(fits_file_path) as hdul:
    # Iterate over HDUs
    for i, hdu in enumerate(hdul):
        # Access header information
        header = hdu.header

        # Print header information
        print(f"Header of HDU {i}:\n")
        print(repr(header))
        print("\n" + "="*40 + "\n")
# Out:
# Header of HDU 0:
#
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T / There may be standard extensions
# FILENAME= 'junk.fits'          / name of file
# NEXTEND =                    1 / number of extensions in file
#
# ========================================
#
# Header of HDU 1:
#
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  787 / width of table in bytes
# NAXIS2  =                   26
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   38
# TTYPE1  = 'cluster '           / label for field   1
# TFORM1  = '10A     '           / data format of field: ASCII Character
# TTYPE2  = 'fullname'           / label for field   2
# TFORM2  = '25A     '           / data format of field: ASCII Character
# TTYPE3  = 'cluster_id'         / label for field   3
# TFORM3  = '1J      '           / data format of field: 4-byte INTEGER
# TTYPE4  = 'RA_Best '           / label for field   4
# TFORM4  = '1E      '           / data format of field: 4-byte REAL
# TUNIT4  = 'deg     '           / physical unit of field
# TTYPE5  = 'DEC_Best'           / label for field   5
# TFORM5  = '1E      '           / data format of field: 4-byte REAL
# TUNIT5  = 'deg     '           / physical unit of field
# TTYPE6  = 'RA_GMOS '           / label for field   6
# TFORM6  = '1E      '           / data format of field: 4-byte REAL
# TUNIT6  = 'deg     '           / physical unit of field
# TTYPE7  = 'DEC_GMOS'           / label for field   7
# TFORM7  = '1D      '           / data format of field: 8-byte DOUBLE
# TUNIT7  = 'deg     '           / physical unit of field
# TTYPE8  = 'PA_deg  '           / label for field   8
# TFORM8  = '1D      '           / data format of field: 8-byte DOUBLE
# TTYPE9  = 'Redshift'           / label for field   9
# TFORM9  = '1D      '           / data format of field: 8-byte DOUBLE
# TTYPE10 = 'vdisp   '           / label for field  10
# TFORM10 = '1E      '           / data format of field: 4-byte REAL
# TUNIT10 = 'km/s    '           / physical unit of field
# TTYPE11 = 'vdisp_err'          / label for field  11
# TFORM11 = '1E      '           / data format of field: 4-byte REAL
# TUNIT11 = 'km/s    '           / physical unit of field
# TTYPE12 = 'gogreen_m1'         / label for field  12
# TFORM12 = '20A     '           / data format of field: ASCII Character
# TUNIT12 = 'null    '           / physical unit of field
# TTYPE13 = 'gogreen_m2'         / label for field  13
# TFORM13 = '20A     '           / data format of field: ASCII Character
# TTYPE14 = 'gogreen_m3'         / label for field  14
# TFORM14 = '20A     '           / data format of field: ASCII Character
# TTYPE15 = 'gogreen_m4'         / label for field  15
# TFORM15 = '20A     '           / data format of field: ASCII Character
# TTYPE16 = 'gogreen_m5'         / label for field  16
# TFORM16 = '20A     '           / data format of field: ASCII Character
# TTYPE17 = 'gogreen_m6'         / label for field  17
# TFORM17 = '20A     '           / data format of field: ASCII Character
# TTYPE18 = 'gclass_m1'          / label for field  18
# TFORM18 = '14A     '           / data format of field: ASCII Character
# TTYPE19 = 'gclass_m2'          / label for field  19
# TFORM19 = '14A     '           / data format of field: ASCII Character
# TTYPE20 = 'gclass_m3'          / label for field  20
# TFORM20 = '14A     '           / data format of field: ASCII Character
# TTYPE21 = 'gclass_m4'          / label for field  21
# TFORM21 = '14A     '           / data format of field: ASCII Character
# TTYPE22 = 'gclass_m5'          / label for field  22
# TFORM22 = '14A     '           / data format of field: ASCII Character
# TTYPE23 = 'Kphot_cat'          / label for field  23
# TFORM23 = '40A     '           / data format of field: ASCII Character
# TUNIT23 = 'null    '           / physical unit of field
# TTYPE24 = 'photoz_cat'         / label for field  24
# TFORM24 = '40A     '           / data format of field: ASCII Character
# TTYPE25 = 'stelmass_cat'       / label for field  25
# TFORM25 = '40A     '           / data format of field: ASCII Character
# TTYPE26 = 'IMAGE_U '           / label for field  26
# TFORM26 = '30A     '           / data format of field: ASCII Character
# TTYPE27 = 'IMAGE_B '           / label for field  27
# TFORM27 = '30A     '           / data format of field: ASCII Character
# TTYPE28 = 'IMAGE_G '           / label for field  28
# TFORM28 = '30A     '           / data format of field: ASCII Character
# TTYPE29 = 'IMAGE_V '           / label for field  29
# TFORM29 = '30A     '           / data format of field: ASCII Character
# TTYPE30 = 'IMAGE_R '           / label for field  30
# TFORM30 = '30A     '           / data format of field: ASCII Character
# TTYPE31 = 'IMAGE_I '           / label for field  31
# TFORM31 = '30A     '           / data format of field: ASCII Character
# TTYPE32 = 'IMAGE_Z '           / label for field  32
# TFORM32 = '30A     '           / data format of field: ASCII Character
# TTYPE33 = 'IMAGE_J '           / label for field  33
# TFORM33 = '30A     '           / data format of field: ASCII Character
# TTYPE34 = 'IMAGE_J1'           / label for field  34
# TFORM34 = '40A     '           / data format of field: ASCII Character
# TTYPE35 = 'IMAGE_Y '           / label for field  35
# TFORM35 = '30A     '           / data format of field: ASCII Character
# TTYPE36 = 'IMAGE_K '           / label for field  36
# TFORM36 = '30A     '           / data format of field: ASCII Character
# TTYPE37 = 'IMAGE_IRAC1'        / label for field  37
# TFORM37 = '30A     '           / data format of field: ASCII Character
# TDISP1  = 'A10     '           / display format
# TDISP2  = 'A25     '           / display format
# TDISP3  = 'I11     '           / display format
# TNULL3  =          -2147483647 / undefined value for column
# TDISP4  = 'G15.7   '           / display format
# TDISP5  = 'G15.7   '           / display format
# TDISP6  = 'G15.7   '           / display format
# TDISP7  = 'G25.16  '           / display format
# TDISP8  = 'G25.16  '           / display format
# TDISP9  = 'G25.16  '           / display format
# TDISP10 = 'G15.7   '           / display format
# TDISP11 = 'G15.7   '           / display format
# TDISP12 = 'A20     '           / display format
# TDISP13 = 'A20     '           / display format
# TDISP14 = 'A20     '           / display format
# TDISP15 = 'A20     '           / display format
# TDISP16 = 'A20     '           / display format
# TDISP17 = 'A20     '           / display format
# TDISP18 = 'A14     '           / display format
# TDISP19 = 'A14     '           / display format
# TDISP20 = 'A14     '           / display format
# TDISP21 = 'A14     '           / display format
# TDISP22 = 'A14     '           / display format
# TDISP23 = 'A40     '           / display format
# TDISP24 = 'A40     '           / display format
# TDISP25 = 'A40     '           / display format
# TDISP26 = 'A30     '           / display format
# TDISP27 = 'A30     '           / display format
# TDISP28 = 'A30     '           / display format
# TDISP29 = 'A30     '           / display format
# TDISP30 = 'A30     '           / display format
# TDISP31 = 'A30     '           / display format
# TDISP32 = 'A30     '           / display format
# TDISP33 = 'A30     '           / display format
# TDISP34 = 'A40     '           / display format
# TDISP35 = 'A30     '           / display format
# TDISP36 = 'A30     '           / display format
# TDISP37 = 'A30     '           / display format
# DATE-HDU= '2015-08-10T20:09:36 UT'
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-21T16:52:44
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-21T16:54:21
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-21T17:23:28
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-21T17:25:45
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-21T17:32:52
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-25T09:33:19
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-25T09:55:17
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-30T10:41:55
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-30T10:50:52
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-30T10:53:02
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-30T10:54:53
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-30T18:57:24
# HISTORY File modified by user 'gilbank' with fv  on 2015-08-31T11:28:52
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-01T12:00:17
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-02T09:31:11
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-02T09:37:57
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-02T10:01:01
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-02T16:53:45
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-02T17:00:16
# HISTORY File modified by user 'gilbank' with fv  on 2015-09-02T17:12:09
# HISTORY File modified by user 'gilbank' with fv  on 2015-10-16T14:15:17
# HISTORY File modified by user 'gilbank' with fv  on 2015-10-16T14:18:06
# HISTORY File modified by user 'gilbank' with fv  on 2016-01-21T10:22:58
# HISTORY File modified by user 'gilbank' with fv  on 2016-01-21T12:37:18
# HISTORY File modified by user 'gilbank' with fv  on 2016-01-21T15:16:11
# TTYPE38 = 'Preimage'           / label for field
# TFORM38 = '24A     '           / format of field
# TUNIT38 = '        '           / column units
# TDISP38 = 'A24     '           / display format
#
# ========================================

# %%
with fits.open(fits_file_path) as hdul:
    # Access data from the first extension
    data_extension = hdul[1].data

    # Access header information of the first extension
    #header_extension = hdul[1].header

    # Print the header information of the first extension
    #print(repr(header_extension))

    # Print the names of the clusters
    print("Cluster Names:")
    print(data_extension['cluster'])
    print(data_extension['stelmass_cat'])
    # Print the positions of the clusters
    print("RA (Right Ascension):", data_extension['RA_Best'])
    print("DEC (Declination):", data_extension['DEC_Best'])
    print("stellar mass:", data_extension['stelmass_cat'])
# Out:
# Cluster Names:
# ['COSMOS-125' 'COSMOS-221' 'COSMOS-28' 'COSMOS-63' 'SPT0205' 'SPT0546'
#  'SPT2106' 'SXDF49' 'SXDF64' 'SXDF76' 'SXDF76b' 'SXDF87' 'SpARCS0035'
#  'SpARCS0219' 'SpARCS0335' 'SpARCS1033' 'SpARCS1034' 'SpARCS1051'
#  'SpARCS1616' 'SpARCS1634' 'SpARCS1638' 'SpARCS0034' 'SpARCS0036'
#  'SpARCS0215' 'SpARCS1047' 'SpARCS1613']
# ['UVISTA_final_colors_sfrs_v4.1.dat' 'UVISTA_final_colors_sfrs_v4.1.dat'
#  'UVISTA_final_colors_sfrs_v4.1.dat' 'UVISTA_final_colors_sfrs_v4.1.dat'
#  'SPTCL-0205_totalall_Ks.fout' 'SPTCL-0546_totalall_Ks.fout'
#  'SPTCL-2106_totalall_Ks.fout' 'SPLASH_SXDF_Mehta_v1p6.fits'
#  'SPLASH_SXDF_Mehta_v1p6.fits' 'SPLASH_SXDF_Mehta_v1p6.fits'
#  'SPLASH_SXDF_Mehta_v1p6.fits' 'SPLASH_SXDF_Mehta_v1p6.fits'
#  'SpARCS-0035_totalall_Ks.fout' 'SpARCS-0219_totalall_Ks.fout'
#  'SpARCS-0335_totalall_Ks.fout' '' 'SpARCS-1034_totalall_Ks.fout'
#  'SpARCS-1051_totalall_Ks.fout' 'SpARCS-1616_totalall_Ks.fout'
#  'SpARCS-1634_totalall_Ks.fout' 'SpARCS-1638_totalall_Ks.fout'
#  'SpARCS-0034_v2.0.fout' 'SpARCS-0036_v2.0.fout' 'SpARCS-0215_v2.0.fout'
#  'SpARCS-1047_v2.0.fout' 'SpARCS-1613_v2.0.fout']
# RA (Right Ascension): [150.6208  150.562   149.4692  150.359    31.451    86.6403  316.5191
#   34.4996   34.3319   34.7461   34.7474   34.536     8.957    34.9315
#   53.7648  158.3565  158.706   162.79675 244.1722  248.6542  249.7152
#    8.67512   9.18756  33.84996 161.8893  243.311  ]
# DEC (Declination): [  2.1675     2.5031     1.6685     1.9352   -58.4803   -53.761
#  -58.7411    -5.0649    -5.2067    -5.3041    -5.3235    -5.063
#  -43.206604  -5.5249   -29.48217   57.89      58.30919   58.30075
#   55.7534    40.3637    40.64525  -43.1315   -44.1805    -3.72561
#   57.68706   56.825   ]
# stellar mass: ['UVISTA_final_colors_sfrs_v4.1.dat' 'UVISTA_final_colors_sfrs_v4.1.dat'
#  'UVISTA_final_colors_sfrs_v4.1.dat' 'UVISTA_final_colors_sfrs_v4.1.dat'
#  'SPTCL-0205_totalall_Ks.fout' 'SPTCL-0546_totalall_Ks.fout'
#  'SPTCL-2106_totalall_Ks.fout' 'SPLASH_SXDF_Mehta_v1p6.fits'
#  'SPLASH_SXDF_Mehta_v1p6.fits' 'SPLASH_SXDF_Mehta_v1p6.fits'
#  'SPLASH_SXDF_Mehta_v1p6.fits' 'SPLASH_SXDF_Mehta_v1p6.fits'
#  'SpARCS-0035_totalall_Ks.fout' 'SpARCS-0219_totalall_Ks.fout'
#  'SpARCS-0335_totalall_Ks.fout' '' 'SpARCS-1034_totalall_Ks.fout'
#  'SpARCS-1051_totalall_Ks.fout' 'SpARCS-1616_totalall_Ks.fout'
#  'SpARCS-1634_totalall_Ks.fout' 'SpARCS-1638_totalall_Ks.fout'
#  'SpARCS-0034_v2.0.fout' 'SpARCS-0036_v2.0.fout' 'SpARCS-0215_v2.0.fout'
#  'SpARCS-1047_v2.0.fout' 'SpARCS-1613_v2.0.fout']

# %%
# Extracted data
cluster_names = ['COSMOS-125', 'COSMOS-221', 'COSMOS-28', 'COSMOS-63', 'SPT0205', 'SPT0546',
                 'SPT2106', 'SXDF49', 'SXDF64', 'SXDF76', 'SXDF76b', 'SXDF87', 'SpARCS0035',
                 'SpARCS0219', 'SpARCS0335', 'SpARCS1033', 'SpARCS1034', 'SpARCS1051',
                 'SpARCS1616', 'SpARCS1634', 'SpARCS1638', 'SpARCS0034', 'SpARCS0036',
                 'SpARCS0215', 'SpARCS1047', 'SpARCS1613']

ra_values = [150.6208, 150.562, 149.4692, 150.359, 31.451, 86.6403, 316.5191,
             34.4996, 34.3319, 34.7461, 34.7474, 34.536, 8.957, 34.9315,
             53.7648, 158.3565, 158.706, 162.79675, 244.1722, 248.6542, 249.7152,
             8.67512, 9.18756, 33.84996, 161.8893, 243.311]

dec_values = [2.1675, 2.5031, 1.6685, 1.9352, -58.4803, -53.761, -58.7411,
              -5.0649, -5.2067, -5.3041, -5.3235, -5.063, -43.206604, -5.5249,
              -29.48217, 57.89, 58.30919, 58.30075, 55.7534, 40.3637, 40.64525,
              -43.1315, -44.1805, -3.72561, 57.68706, 56.825]

data_list = [{'Cluster Names': name, 'RA': ra, 'DEC': dec} for name, ra, dec in zip(cluster_names, ra_values, dec_values)]

# Display the list of dictionaries
for item in data_list:
    print(item)
# Out:
# {'Cluster Names': 'COSMOS-125', 'RA': 150.6208, 'DEC': 2.1675}
# {'Cluster Names': 'COSMOS-221', 'RA': 150.562, 'DEC': 2.5031}
# {'Cluster Names': 'COSMOS-28', 'RA': 149.4692, 'DEC': 1.6685}
# {'Cluster Names': 'COSMOS-63', 'RA': 150.359, 'DEC': 1.9352}
# {'Cluster Names': 'SPT0205', 'RA': 31.451, 'DEC': -58.4803}
# {'Cluster Names': 'SPT0546', 'RA': 86.6403, 'DEC': -53.761}
# {'Cluster Names': 'SPT2106', 'RA': 316.5191, 'DEC': -58.7411}
# {'Cluster Names': 'SXDF49', 'RA': 34.4996, 'DEC': -5.0649}
# {'Cluster Names': 'SXDF64', 'RA': 34.3319, 'DEC': -5.2067}
# {'Cluster Names': 'SXDF76', 'RA': 34.7461, 'DEC': -5.3041}
# {'Cluster Names': 'SXDF76b', 'RA': 34.7474, 'DEC': -5.3235}
# {'Cluster Names': 'SXDF87', 'RA': 34.536, 'DEC': -5.063}
# {'Cluster Names': 'SpARCS0035', 'RA': 8.957, 'DEC': -43.206604}
# {'Cluster Names': 'SpARCS0219', 'RA': 34.9315, 'DEC': -5.5249}
# {'Cluster Names': 'SpARCS0335', 'RA': 53.7648, 'DEC': -29.48217}
# {'Cluster Names': 'SpARCS1033', 'RA': 158.3565, 'DEC': 57.89}
# {'Cluster Names': 'SpARCS1034', 'RA': 158.706, 'DEC': 58.30919}
# {'Cluster Names': 'SpARCS1051', 'RA': 162.79675, 'DEC': 58.30075}
# {'Cluster Names': 'SpARCS1616', 'RA': 244.1722, 'DEC': 55.7534}
# {'Cluster Names': 'SpARCS1634', 'RA': 248.6542, 'DEC': 40.3637}
# {'Cluster Names': 'SpARCS1638', 'RA': 249.7152, 'DEC': 40.64525}
# {'Cluster Names': 'SpARCS0034', 'RA': 8.67512, 'DEC': -43.1315}
# {'Cluster Names': 'SpARCS0036', 'RA': 9.18756, 'DEC': -44.1805}
# {'Cluster Names': 'SpARCS0215', 'RA': 33.84996, 'DEC': -3.72561}
# {'Cluster Names': 'SpARCS1047', 'RA': 161.8893, 'DEC': 57.68706}
# {'Cluster Names': 'SpARCS1613', 'RA': 243.311, 'DEC': 56.825}

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord, Galactic
ra_values = [150.6208, 150.562, 149.4692, 150.359, 31.451, 86.6403, 316.5191,
             34.4996, 34.3319, 34.7461, 34.7474, 34.536, 8.957, 34.9315,
             53.7648, 158.3565, 158.706, 162.79675, 244.1722, 248.6542, 249.7152,
             8.67512, 9.18756, 33.84996, 161.8893, 243.311]

dec_values = [2.1675, 2.5031, 1.6685, 1.9352, -58.4803, -53.761, -58.7411,
              -5.0649, -5.2067, -5.3041, -5.3235, -5.063, -43.206604, -5.5249,
              -29.48217, 57.89, 58.30919, 58.30075, 55.7534, 40.3637, 40.64525,
              -43.1315, -44.1805, -3.72561, 57.68706, 56.825]

# Create a SkyCoord object with RA and Dec
coords = SkyCoord(ra=ra_values*u.degree, dec=dec_values*u.degree, frame='icrs')

# Convert to Galactic coordinates
galactic_coords = coords.transform_to(Galactic)

# Extract Galactic Longitude and Latitude 
galactic_longitude = galactic_coords.l.degree
galactic_latitude = galactic_coords.b.degree
# Display the results
for name, l, b in zip(cluster_names, galactic_longitude, galactic_latitude):
    print(f"Cluster: {name}, Galactic Longitude: {l:.4f}, Galactic Latitude: {b:.4f}")
# Out:
# Cluster: COSMOS-125, Galactic Longitude: 237.2591, Galactic Latitude: 42.5068
# Cluster: COSMOS-221, Galactic Longitude: 236.8421, Galactic Latitude: 42.6545
# Cluster: COSMOS-28, Galactic Longitude: 236.9026, Galactic Latitude: 41.2807
# Cluster: COSMOS-63, Galactic Longitude: 237.3072, Galactic Latitude: 42.1587
# Cluster: SPT0205, Galactic Longitude: 285.5587, Galactic Latitude: -56.0686
# Cluster: SPT0546, Galactic Longitude: 261.4740, Galactic Latitude: -30.9794
# Cluster: SPT2106, Galactic Longitude: 337.3803, Galactic Latitude: -40.2224
# Cluster: SXDF49, Galactic Longitude: 169.8426, Galactic Latitude: -59.8013
# Cluster: SXDF64, Galactic Longitude: 169.7745, Galactic Latitude: -60.0177
# Cluster: SXDF76, Galactic Longitude: 170.5231, Galactic Latitude: -59.8207
# Cluster: SXDF76b, Galactic Longitude: 170.5505, Galactic Latitude: -59.8344
# Cluster: SXDF87, Galactic Longitude: 169.8947, Galactic Latitude: -59.7762
# Cluster: SpARCS0035, Galactic Longitude: 313.0594, Galactic Latitude: -73.6134
# Cluster: SpARCS0219, Galactic Longitude: 171.0895, Galactic Latitude: -59.8636
# Cluster: SpARCS0335, Galactic Longitude: 226.5419, Galactic Latitude: -54.0919
# Cluster: SpARCS1033, Galactic Longitude: 151.4511, Galactic Latitude: 50.9037
# Cluster: SpARCS1034, Galactic Longitude: 150.7458, Galactic Latitude: 50.7962
# Cluster: SpARCS1051, Galactic Longitude: 148.5137, Galactic Latitude: 52.4388
# Cluster: SpARCS1616, Galactic Longitude: 85.5678, Galactic Latitude: 43.6293
# Cluster: SpARCS1634, Galactic Longitude: 64.0947, Galactic Latitude: 42.5728
# Cluster: SpARCS1638, Galactic Longitude: 64.5128, Galactic Latitude: 41.7765
# Cluster: SpARCS0034, Galactic Longitude: 313.8297, Galactic Latitude: -73.6408
# Cluster: SpARCS0036, Galactic Longitude: 311.8134, Galactic Latitude: -72.6936
# Cluster: SpARCS0215, Galactic Longitude: 167.1775, Galactic Latitude: -59.1823
# Cluster: SpARCS1047, Galactic Longitude: 149.7904, Galactic Latitude: 52.4935
# Cluster: SpARCS1613, Galactic Longitude: 87.1793, Galactic Latitude: 43.7686

# %%
# These are the Clusters that fall within the observable region
for i in range(len(cluster_names)):
    # Check if the Galactic Longitude is within the specified range
    if 179.94423568 <= galactic_longitude[i] <= 359.94423568:
        # Print information for clusters within the range
        print(f"Cluster: {cluster_names[i]}, Galactic Longitude: {galactic_longitude[i]}, Galactic Latitude: {galactic_latitude[i]}")
# Out:
# Cluster: COSMOS-125, Galactic Longitude: 237.25914404812224, Galactic Latitude: 42.50681286630174
# Cluster: COSMOS-221, Galactic Longitude: 236.84214956654304, Galactic Latitude: 42.65447312454607
# Cluster: COSMOS-28, Galactic Longitude: 236.90259780484317, Galactic Latitude: 41.28073874299793
# Cluster: COSMOS-63, Galactic Longitude: 237.3072002343638, Galactic Latitude: 42.15874307369241
# Cluster: SPT0205, Galactic Longitude: 285.55867279316857, Galactic Latitude: -56.06857671047569
# Cluster: SPT0546, Galactic Longitude: 261.4740302884961, Galactic Latitude: -30.97937940140743
# Cluster: SPT2106, Galactic Longitude: 337.38033141348274, Galactic Latitude: -40.222438231055
# Cluster: SpARCS0035, Galactic Longitude: 313.0593632277148, Galactic Latitude: -73.61335126262414
# Cluster: SpARCS0335, Galactic Longitude: 226.54191062277545, Galactic Latitude: -54.09186387672532
# Cluster: SpARCS0034, Galactic Longitude: 313.8296982979513, Galactic Latitude: -73.64079953582157
# Cluster: SpARCS0036, Galactic Longitude: 311.8133896530781, Galactic Latitude: -72.69358424918588

# %%
clusters = ['COSMOS-125', 'COSMOS-221', 'COSMOS-28', 'COSMOS-63', 'SPT0205', 'SPT0546', 'SPT2106',
            'SpARCS0035', 'SpARCS0335', 'SpARCS0034', 'SpARCS0036']
galactic_longitude = [237.25914404812224, 236.84214956654304, 236.90259780484317, 237.3072002343638,
                       285.55867279316857, 261.4740302884961, 337.38033141348274, 313.0593632277148,
                       226.54191062277545, 313.8296982979513, 311.8133896530781]
galactic_latitude = [42.50681286630174, 42.65447312454607, 41.28073874299793, 42.15874307369241,
                      -56.06857671047569, -30.97937940140743, -40.222438231055, -73.61335126262414,
                      -54.09186387672532, -73.64079953582157, -72.69358424918588]

# Plot the sky map
plt.figure(figsize=(10, 6))
plt.scatter(galactic_longitude, galactic_latitude, label='Clusters', color='red', marker='o')

# Annotate each point with the cluster name
for i, cluster in enumerate(clusters):
    plt.annotate(cluster, (galactic_longitude[i], galactic_latitude[i]), textcoords="offset points", xytext=(3,5), ha='center')

plt.xlabel('Galactic Longitude (degrees)')
plt.ylabel('Galactic Latitude (degrees)')
plt.title('Sky Map with Clusters')
plt.ylim(-90, 90)
plt.grid(True)
plt.legend()
plt.show()

# %%
from astropy.io import fits


# Get data from HDU 1
data = hdul[1].data

# Extract cluster names and stel mass values
cluster_names = data['fullname']
stel_mass = data['stelmass_cat']

# Print the values along with the cluster names
for cluster_name, mass in zip(cluster_names, stel_mass):
    print(f'Cluster Name: {cluster_name}, Stellar Mass: {mass}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 from astropy.io import fits
#       4 # Get data from HDU 1
# ----> 5 data = hdul[1].data
#       7 # Extract cluster names and stel mass values
#       8 cluster_names = data['fullname']
#
# File ~\anaconda3\Lib\site-packages\astropy\utils\decorators.py:837, in lazyproperty.__get__(self, obj, owner)
#     835         val = obj_dict.get(self._key, _NotFound)
#     836         if val is _NotFound:
# --> 837             val = self.fget(obj)
#     838             obj_dict[self._key] = val
#     839 return val
#
# File ~\anaconda3\Lib\site-packages\astropy\io\fits\hdu\table.py:442, in _TableBaseHDU.data(self)
#     440 @lazyproperty
#     441 def data(self):
# --> 442     data = self._get_tbdata()
#     443     data._coldefs = self.columns
#     444     data._character_as_bytes = self._character_as_bytes
#
# File ~\anaconda3\Lib\site-packages\astropy\io\fits\hdu\table.py:194, in _TableLikeHDU._get_tbdata(self)
#     192     data = raw_data[:tbsize].view(dtype=columns.dtype, type=np.rec.recarray)
#     193 else:
# --> 194     raw_data = self._get_raw_data(self._nrows, columns.dtype, self._data_offset)
#     195     if raw_data is None:
#     196         # This can happen when a brand new table HDU is being created
#     197         # and no data has been assigned to the columns, which case just
#     198         # return an empty array
#     199         raw_data = np.array([], dtype=columns.dtype)
#
# File ~\anaconda3\Lib\site-packages\astropy\io\fits\hdu\base.py:547, in _BaseHDU._get_raw_data(self, shape, code, offset)
#     545     return np.ndarray(shape, dtype=code, buffer=self._buffer, offset=offset)
#     546 elif self._file:
# --> 547     return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     548 else:
#     549     return None
#
# File ~\anaconda3\Lib\site-packages\astropy\io\fits\file.py:329, in _File.readarray(self, size, offset, dtype, shape)
#     324     elif actualsize < size:
#     325         raise ValueError(
#     326             f"size {size} is too many bytes for a {shape} array of {dtype}"
#     327         )
# --> 329 filepos = self._file.tell()
#     331 try:
#     332     if self.memmap:
#
# ValueError: I/O operation on closed file
