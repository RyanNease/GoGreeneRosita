# %%
# I began by importing the file from the eROSITA data paper
#https://arxiv.org/pdf/2402.08452. This paper discusses the 
# data collected from eROSITA and the specific region we discussed 
# in the last jupyter notebook


import tarfile
from astropy.io import fits
import os
import numpy as np
import matplotlib.pyplot as plt
# Specify the path to your tarball file
tarball_path = 'erass1cl_primary_v3.2.fits (1).tgz'

# Extract the tarball
with tarfile.open(tarball_path, 'r:gz') as tar:
    # Extract all files to a temporary directory
    temp_dir = 'Documents/GoGreen'
    tar.extractall(temp_dir)

# List the files in the temporary directory
files_in_temp_dir = os.listdir(temp_dir)

# Find the FITS file in the temporary directory
fits_file_name = [file for file in files_in_temp_dir if file.endswith('.fits')][0]
fits_file_path = os.path.join(temp_dir, fits_file_name)

# Open the FITS file
fits_file = fits.open(fits_file_path)

# %%
# Check the number of HDUs in the file
num_hdus = len(fits_file)
print(f'Number of HDUs: {num_hdus}')

# Print information about each HDU
for i in range(num_hdus):
    hdu_info = fits_file[i].header
    #print(f'\nHDU {i} Info:')
    #print(hdu_info)

# Access HDU0 
hdu0 = fits_file[0]
# Access HDU1
hdu1 = fits_file[1]
# Out:
# Number of HDUs: 2

# %%
# I used this box to figure out some information from the 
# columns of the data


data_table = fits_file[1].data

#Print the values in the given column
names = data_table['CTS500']
print(names)
# Out:
# [ 48.2 189.5  30.3 ...  62.5  13.4 188. ]

# %%
data_table = fits_file[1].data

# Assuming "RA" and "Dec" are the column names for Right Ascension and Declination respectively
ras = data_table["RA"]
decs = data_table["Dec"]

# Print both RA and Dec coordinates along with their column numbers
#for i, (ra, dec) in enumerate(zip(ras, decs), start=1):
    #print(f"Column {i}: RA={ra}, Dec={dec}")

# %%
# I used this box to learn more about the Match Name column and found out
# that by searching through match name I coul find if it was titled as 
# GOGREEN-GCLASS giving me my clusters from the GoGreen data.

data_table = fits_file[1].data

#Extract data for the columns
match_names = data_table["MATCH_NAME"]
ras = data_table["RA"]
decs = data_table["Dec"]
temp = data_table['kT']
# Create a boolean mask to filter rows based on the condition
mask = [True if "GOGREEN-GCLASS" in name else False for name in match_names]

# Iterate over the filtered rows using the boolean mask
for i, (name, ra, dec) in enumerate(zip(match_names[mask], ras[mask], decs[mask])):
    # Print the following information
    print("MATCH_NAME:", name)
    print("RA:", ra)
    print("Dec:", dec)
    print("ICMTEMP", temp)
# Out:
# MATCH_NAME: ACTDR5_ACT-CL J0205.7-5829,GOGREEN-GCLASS_SPT0205,KIM-HIGHZ-LENSING_4,SPT2500D_SPT-CLJ0205-5829,XCLASS_3370
# RA: 31.447910971701344
# Dec: -58.483919215928594
# ICMTEMP [ 1.9  -1.    1.79 ... -1.   -1.    4.18]
# MATCH_NAME: ACTDR5_ACT-CL J0546.6-5345,GOGREEN-GCLASS_SPT0546,KIM-HIGHZ-LENSING_44,MARDY3_MARDJ054638.8-534424,SPT2500D_SPT-CLJ0546-5345
# RA: 86.65905614246141
# Dec: -53.7580295917548
# ICMTEMP [ 1.9  -1.    1.79 ... -1.   -1.    4.18]
# MATCH_NAME: ACTDR5_ACT-CL J2106.0-5844,GOGREEN-GCLASS_SPT2106,KIM-HIGHZ-LENSING_1,SPT2500D_SPT-CLJ2106-5844,XCLASS_24787
# RA: 316.51733609532954
# Dec: -58.74039463638295
# ICMTEMP [ 1.9  -1.    1.79 ... -1.   -1.    4.18]

# %%
# I tried to search for the GoGreen clusters by name

# List of cluster names to search
cluster_names_to_search = ['COSMOS-125', 'COSMOS-221', 'COSMOS-28', 'COSMOS-63', 'SPT0205', 'SPT0546', 'SPT2106',
                            'SpARCS0035', 'SpARCS0335', 'SpARCS0034', 'SpARCS0036']

# Get the 'MATCH_NAME' values from the data table
names = data_table['NAME']

# Search for the specified cluster names using boolean indexing
found_clusters_mask = np.isin(names, cluster_names_to_search)

# Filter the data based on the boolean mask
found_clusters = names[found_clusters_mask]

# Print the found clusters
print(found_clusters)
# Out:
# []

# %%
# I'm just checking some of the sections in the data and 
# figuring out how many clusters I'm working with



# Cluster names
cluster_names = data_table['NAME']

# Calculate the total number of clusters
total_clusters = len(cluster_names)

print(f'Total Number of Clusters: {total_clusters}')
# Out:
# Total Number of Clusters: 12247

# %%
# This graph was created to show all of the clusters within the data
# on a plot of Dec vs RA

# Extract RA and DEC columns
ra = data_table['RA']
dec = data_table['DEC']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(ra, dec, s=5, alpha=0.5)
plt.title('Clusters Distribution')
plt.xlabel('RA (degrees)')
plt.ylabel('DEC (degrees)')
plt.grid(True)
plt.show()

# %%
# This is the same graph as above but it is color coated by 
# the redshift of each of the clusters


# Extract RA, DEC, and redshift columns
ra = data_table['RA']
dec = data_table['DEC']
redshift = data_table['BEST_Z']

# Create a scatter plot with redshift information
plt.figure(figsize=(10, 6))
scatter = plt.scatter(ra, dec, c=redshift, s=5, alpha=0.5, cmap='viridis') 
plt.title('Clusters Distribution with Redshift')
plt.xlabel('RA (degrees)')
plt.ylabel('DEC (degrees)')
plt.colorbar(scatter, label='Redshift (BEST_Z)')
plt.grid(True)
plt.savefig('ClusterDistributionredshift.png')
plt.show()

# %%
# This is the same graph as above but this time i took the clusters 
# that we found from the other jupyter notebook and overplotted this 
# on this graph to show where the clusters we are looking for in the 
# eROSITA data should be located



# Extract RA, DEC, and redshift columns
ra = data_table['RA']
dec = data_table['DEC']
redshift = data_table['BEST_Z']

# Specify RA and DEC coordinates for known clusters
known_clusters_ra = [150.6208, 150.562, 149.4692,150.359,31.451,86.6403,316.5191,8.957,8.67512,9.18756]  # Add your specific RA coordinates here
known_clusters_dec = [2.1675, 2.5031, 1.6685,1.9352,-58.4803,-53.761,-58.7411,-43.206604,-43.1315,-44.1805]  # Add your specific DEC coordinates here

# Create a scatter plot with redshift information
plt.figure(figsize=(10, 6))

# Scatter plot for all data points
scatter = plt.scatter(ra, dec, c=redshift, s=5, alpha=0.5, cmap='viridis') 

# Mark known clusters with red 'x' markers
plt.scatter(known_clusters_ra, known_clusters_dec, marker='x', color='red', label='Known Clusters')

plt.title('Clusters Distribution with Redshift and Known Clusters')
plt.xlabel('RA (degrees)')
plt.ylabel('DEC (degrees)')

# Add a legend to label the red 'x' markers
plt.legend()

plt.colorbar(scatter, label='Redshift (BEST_Z)')
plt.grid(True)
plt.savefig('ClusterDistributionredshiftwithclusters.png')
plt.show()

# %%
# This is another type of graph similar to the one above called a 
# Mollweide projection. I just wanted to get another look at the clusters 
# from the data and overplot where the clusters from the last notebook
# should be located




# Extract RA, DEC, and redshift columns
ra = data_table['RA']
dec = data_table['DEC']
redshift = data_table['BEST_Z']

# Calculate rotation angle 
rotation_angle = 180 - 180  

# Rotate RA coordinates
ra_mollweide = np.remainder(ra + 360 - 180 + rotation_angle, 360) - 180
ra_mollweide = np.radians(ra_mollweide)

# Specify RA and DEC coordinates for known clusters
known_clusters_ra = np.radians([150.6208, 150.562, 149.4692, 150.359, 31.451, 86.6403, 316.5191, 8.957, 8.67512, 9.18756])
known_clusters_dec = np.radians([2.1675, 2.5031, 1.6685, 1.9352, -58.4803, -53.761, -58.7411, -43.206604, -43.1315, -44.1805])

# Create a Mollweide scatter plot with redshift information
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="mollweide")
scatter = ax.scatter(ra_mollweide, np.radians(dec), c=redshift, s=5, alpha=0.5, cmap='viridis')
ax.set_title('Clusters Distribution with Redshift and Known Clusters')
ax.set_xlabel('RA (degrees)')
ax.set_ylabel('DEC (degrees)')

# Plot x's for known clusters
ax.scatter(known_clusters_ra, known_clusters_dec, marker='x', color='red', label='Known Clusters')

plt.colorbar(scatter, label='Redshift (BEST_Z)')
plt.grid(True)
plt.legend()
plt.savefig('mollweide_plot.png')
plt.show()

# %%
# Through working the the paper that went with the eROSTIA data release 
# it cross references the eROSTIA with the GoGreen clusters and shows 
# that there should be 11 clusters in the data but only 3 of the clusters
# actually appear in the data (meaning the other 8 are too faint to be detected). 
# This graph is the same as the graph above but this time overplotted from the 
# eROSITA data the 3 clusters from the GoGreen data that were detected.



# Extract necessary columns
ra = data_table['RA']
dec = data_table['DEC']
redshift = data_table['BEST_Z']

# Create a scatter plot with redshift information
plt.figure(figsize=(10, 6))
scatter = plt.scatter(ra, dec, c=redshift, s=5, alpha=0.5, cmap='viridis')
plt.title('Clusters Distribution with Redshift and Known Clusters')
plt.xlabel('RA (degrees)')
plt.ylabel('DEC (degrees)')

# Overplot filtered data based on the boolean mask
for i in range(len(mask)):
    if mask[i]:
        plt.scatter(ras[i], decs[i], c='blue', marker='x')  # Change color to blue

        # Annotate each point with its label
        label_name = match_names[i].split(',')[1].strip()
        plt.annotate(label_name, (ras[i], decs[i]), textcoords="offset points", xytext=(5,5), ha='center')

# add colorbar for redshift
plt.colorbar(scatter, label='Redshift (BEST_Z)')
plt.grid(True)
plt.savefig('scatter_plot_with_filtered_data.png')
plt.show()

# %%
# Again this is a mollweide projection of the same graph as above with
# the 3 clusters from the GoGreen data that were detected in the 
# eROSTIA data




# Extract necessary columns
ra = data_table['RA']
dec = data_table['DEC']
redshift = data_table['BEST_Z']

# Calculate rotation angle
rotation_angle = 180 - 180

# Rotate RA coordinates
ra_mollweide = np.remainder(ra + 360 - 180 + rotation_angle, 360) - 180
ra_mollweide = np.radians(ra_mollweide)

# Create a Mollweide scatter plot with redshift information
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="mollweide")
scatter = ax.scatter(ra_mollweide, np.radians(dec), c=redshift, s=5, alpha=0.5, cmap='viridis')
ax.set_title('Clusters Distribution with Redshift and Known Clusters')
ax.set_xlabel('RA (degrees)')
ax.set_ylabel('DEC (degrees)')

# Overplot filtered data based on the boolean mask
for i in range(len(mask)):
    if mask[i]:
        label_name = match_names[i].split(',')[1].strip()
        ax.scatter(np.radians(ras[i]), np.radians(decs[i]), c='red', marker='x', label=label_name)

        # Annotate each point with its label
        ax.annotate(label_name, (np.radians(ras[i]), np.radians(decs[i])), textcoords="offset points", xytext=(5,5), ha='center')

#add colorbar for redshift
plt.colorbar(scatter, label='Redshift (BEST_Z)')
plt.grid(True)
plt.legend()
plt.savefig('mollweide_plot_with_filtered_data.png')
plt.show()

# %%
# I included this graph of the eROSTIA data because I found it interesting.
# Its a histogram of all the 12k + clusters vs. their redshift. As we can
# see as the redshift gets bigger the less and less clusters that are able
# to be detected.




import matplotlib.pyplot as plt

# column EXT_LIKE
ext_like_values = data_table['EXT_LIKE']

# Filter data based on EXT_LIKE > 3
filtered_data = data_table[ext_like_values > 3]

# Create a histogram
plt.hist(filtered_data['BEST_Z'], bins=30, color='grey', alpha=0.7)
plt.xlabel('Redshift')
plt.ylabel('Number of Clusters')
plt.title('Redshift Distribution of Clusters with EXT_LIKE > 3')

# Find the median redshift in the filtered data
median_redshift = np.median(filtered_data['BEST_Z'])

# Display the median in the top right part of the graph
plt.text(0.95, 0.95, f'eRASS1 Zmed= {median_redshift:.2f}', ha='right', va='top', transform=plt.gca().transAxes, bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.5'))
plt.savefig('Histogram.png')
plt.show()

# %%
# This graph is the soft band luminosity of all the eROSITA clusters vs the redshift 
# color coated in Log10(l_EXT). I overplotted our 3 GoGreen clusters on this graph and 
# as we can see there is a required luminosity limit for the clusters to be detected in
# the eROSITA data.




data_table = fits_file[1].data

Luminosity = data_table['L300kpc'] * 10**42
redshift = data_table['BEST_Z']
Lext = data_table['EXT_LIKE'] 

# Calculate the logarithm of Lext
loglext = np.log10(Lext)

# Plotting the luminosity vs. redshift
plt.figure(figsize=(10, 6))
plt.scatter(redshift, Luminosity, c=loglext, cmap='viridis', s=20, alpha=0.7, label='All Clusters')

# Extracting data for overplotting
match_names = data_table["MATCH_NAME"]
#ras = data_table["RA"]
#decs = data_table["Dec"]

# Create a boolean mask to filter rows
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])

# Plot filtered data points
plt.scatter(redshift[mask], Luminosity[mask], color='red', marker='x', s=20, alpha=0.7, label='Filtered Data')

plt.xlabel('Redshift')
plt.ylabel('Luminosity (ergs^-1)')
plt.title('Soft Band Luminosity Distribution vs. Redshift')
plt.colorbar(label='log10(Lext)')
plt.legend()
plt.grid(True)

# Set y-axis limits
plt.ylim(1e41, 1e46)

# Set y-axis ticks with logarithmic scale
plt.yscale('log')
plt.savefig('soft Band Luminosity.png')
plt.show()

# %%
# This is a graph of all the clusters of the eROSTIA data. This graph shows
# Luminosity vs ICM Temperature color coated in log10(counts). I plotted our 3 
# GoGreen clusters over the graph but only one showed up as the other 2's ICM
# Temperature is unknown.




data_table = fits_file[1].data

Luminosity = data_table['L300kpc']*10**42
ICM_Temp = data_table['kT']
Counts = data_table['CTS500']

# Calculate the logarithm of counts
logcounts = np.log10(Counts)

# Plotting Luminosity vs ICM temperature
plt.figure(figsize=(10, 6))
plt.scatter(ICM_Temp, Luminosity, c=logcounts, cmap='viridis', s=20, alpha=0.7, label='All Clusters')

# Extracting data for overplotting
match_names = data_table["MATCH_NAME"]
#ras = data_table["RA"]
#decs = data_table["Dec"]

# Create a boolean mask to filter rows
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])

# Plot filtered data points
plt.scatter(ICM_Temp[mask], Luminosity[mask], color='red', marker='x', s=20, alpha=0.7, label='Filtered Data')

plt.xlabel('ICM Temperature(KeV)')
plt.ylabel('Luminosity(ergs^-1)')
plt.title('Luminosity vs ICM Temperature')
plt.colorbar(label='log10(Counts)')
plt.grid(True)

# Set y-axis/ x-axis limits
plt.ylim(1e41, 1e46)
plt.xlim(1e-1, 1e1)

# Set y-axis/x-axis ticks with logarithmic scale
plt.yscale('log')
plt.xscale('log')

plt.show()
# Out:
# C:\Users\nease\AppData\Local\Temp\ipykernel_28248\3868754246.py:8: RuntimeWarning: divide by zero encountered in log10
#   logcounts = np.log10(Counts)

# %%
# This is a graph of M500 vs Redshift color coated in log10(L_EXT)
# for all the clusters from the eROSITA data. Overplotted on this graph are
# our 3 clusters from the GoGreen data. As we can see, just like with Luminosity,
# there is a required M500 to be detected in the eROSITA data.




data_table = fits_file[1].data

# Extracting data
Mass500 = data_table['M500']*10**13
redshift = data_table['BEST_Z']
Lext = data_table['EXT_LIKE']

# Calculate the logarithm of Lext
loglext = np.log10(Lext)

# Plotting M500 vs Redshift
plt.figure(figsize=(10, 6))
plt.scatter(redshift, Mass500, c=loglext, cmap='viridis', s=20, alpha=0.7, label='All Clusters')


# Extracting data for overplotting
match_names = data_table["MATCH_NAME"]
#ras = data_table["RA"]
#decs = data_table["Dec"]

# Create a boolean mask to filter rows
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])

# Plot filtered data points
plt.scatter(redshift[mask], Mass500[mask], color='red', marker='x', s=20, alpha=0.7, label='Filtered Data')


plt.xlabel('Redshift')
plt.ylabel('M500(10^14 Mass of Sun)')
plt.title('M500 vs. Redshift')
plt.colorbar(label='log10(Lext)')
plt.grid(True)

#Set y-limits and y-scale
plt.ylim(1e12, 1e16)
plt.yscale('log')
plt.savefig('Mass vs redshift.png')
plt.show()

# %%
# This is a graph of Bolemetric Luminosity within R500 vs redshift for
# all the clusters from the eROSITA data. Overplotted are the 3 clusters from
# the GoGreen data. There is a required Bolemetric Luminosity to be detected in the 
# eROSITA data.


data_table = fits_file[1].data

# Extracting data 
Lbol = data_table['Lbol500'] * 10**42
redshift = data_table['BEST_Z']

# Plotting Lbol vs. Redshift
plt.figure(figsize=(10, 6))
plt.scatter(redshift, Lbol, s=20, alpha=0.7, label='All Data')

# Extracting data for overplotting
match_names = data_table["MATCH_NAME"]
#ras = data_table["RA"]
#decs = data_table["Dec"]

# Create a boolean mask to filter rows
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])

# Plot filtered data points
plt.scatter(redshift[mask], Lbol[mask], color='red', marker='x', s=20, alpha=0.7, label='Filtered Data')

# Adding labels and title
plt.xlabel('Redshift')
plt.ylabel('Lbol (ergs^-1)')
plt.title('Bolemetric Luminosity within R500 vs. Redshift')
plt.grid(True)
plt.yscale('log')
plt.legend()

plt.show()

# %%
# This is a graph of all the clusters of the eROSTIA data. This graph shows
# Luminosity vs ICM Temperature color coated in M500. I plotted our 3 
# GoGreen clusters over the graph but only one showed up as the other 2's ICM
# Temperature is unknown.



import numpy as np
import matplotlib.pyplot as plt


Luminosity = data_table['L300kpc'] * 10**42
ICM_Temp = data_table['kT']
Mass500 = data_table['M500'] * 10**13

plt.figure(figsize=(10, 6))
plt.scatter(ICM_Temp, Luminosity, c=Mass500, cmap='viridis', s=20, alpha=0.7, label='All Clusters', vmin=1e13, vmax=1e15)

# Extracting data for overplotting
match_names = data_table["MATCH_NAME"]
# ras = data_table["RA"]
# decs = data_table["Dec"]

# Create a boolean mask to filter rows
filtered_data_x = ICM_Temp[mask]
filtered_data_y = Luminosity[mask]
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])

# Plot filtered data points
plt.scatter(ICM_Temp[mask], Luminosity[mask], color='red', marker='x', s=20, alpha=0.7, label='Filtered Data')

# Adding labels and title
plt.xlabel('ICM Temperature (KeV)')
plt.ylabel('Luminosity (ergs^-1)')
plt.title('Luminosity vs ICM Temperature')
plt.colorbar(label='Mass500')
plt.grid(True)

# Set y-axis/x-axis limits
plt.ylim(1e41, 1e46)
plt.xlim(1e-1, 1e1)

# Set y-axis/x-axis ticks with logarithmic scale
plt.yscale('log')
plt.xscale('log')

plt.legend()
plt.show()

# Print the number of red "x" markers
num_red_x = np.sum(mask)
print("Number of red 'x' markers:", num_red_x)

# Print the luminosity and ICM temperature for the red "x" markers
print("Luminosity and ICM Temperature for red 'x' markers:")
for i in range(num_red_x):
    print(f"Luminosity: {filtered_data_y[i]}, ICM Temperature: {filtered_data_x[i]}")
# Out:
# Number of red 'x' markers: 3
# Luminosity and ICM Temperature for red 'x' markers:
# Luminosity: 4.74189e+44, ICM Temperature: -1.0
# Luminosity: 6.02834e+44, ICM Temperature: 5.52
# Luminosity: 1.11231e+45, ICM Temperature: -1.0

# %%
# So one of the last things that I wanted to do is figure out why
# some of the other clusters from the GoGreen data that should
# be detected in this area of the sky arent. To do this I took 
# 4 of the clusters and converted their M200 to Luminosity500.


def calculate_luminosity(Mh):
    Lx = 10**(28.46) * (Mh)**1.024
    return Lx

# Call the function
Sparc0335 = calculate_luminosity(1.8*10**14)
Sparc0035 = calculate_luminosity(3.8*10**14)
Sparc0034 = calculate_luminosity(.6*10**14)  
Sparc0036 = calculate_luminosity(3.6*10**14)  

# Print the results
print("Result for Sparcs0335:", Sparc0335)
print("Result for Sparc0035:", Sparc0035)
print("Result for Sparc0034:", Sparc0034)
print("Result for Sparc0036:", Sparc0036)
# Out:
# Result for Sparcs0335: 1.141297971125998e+43
# Result for Sparc0035: 2.453004827721625e+43
# Result for Sparc0034: 3.7053298950625353e+42
# Result for Sparc0036: 2.3208857434408187e+43

# %%
# Plotting the data from above on a graph of Luminosity vs redshift
# color coated in log10(L_EXT) we can see that the luminosities of 
# the 4 GoGreen clusters that I converted from M200 are too low
# to be detected in the eROSITA sky survey.



import numpy as np
import matplotlib.pyplot as plt

# Define the function to calculate luminosity
def calculate_luminosity(Mh):
    Lx = 10**(28.46) * (Mh)**1.024
    return Lx

# Define masses and cluster names
masses = [1.8e14, 3.8e14, 0.6e14, 3.6e14]
cluster_names = ["Sparc0335", "Sparc0035", "Sparc0034", "Sparc0036"]

# Calculate luminosities
luminosities = [calculate_luminosity(Mh) for Mh in masses]

# Define redshift for these luminosities (assuming redshift of about 1)
redshifts = [1, 1, 1, 1]

# Plotting the luminosity vs. redshift
plt.figure(figsize=(10, 6))
plt.scatter(redshift, Luminosity, c=loglext, cmap='viridis', s=20, alpha=0.7, label='All Clusters')

# Extracting data for overplotting
match_names = data_table["MATCH_NAME"]
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])
plt.scatter(redshift[mask], Luminosity[mask], color='red', marker='x', s=20, alpha=0.7, label='Filtered Data')

# Plot additional luminosities
scatter = plt.scatter(redshifts, luminosities, color='Orange', marker='x', s=50, label='Additional Data')

# Add labels for each cluster
for i, txt in enumerate(cluster_names):
    plt.text(redshifts[i], luminosities[i], txt, ha='right', va='bottom', fontsize=8, color='black')

plt.xlabel('Redshift')
plt.ylabel('Luminosity (ergs^-1)')
plt.title('Soft Band Luminosity Distribution vs. Redshift')
plt.colorbar(label='log10(Lext)')
plt.legend()
plt.grid(True)

# Set y-axis limits
plt.ylim(1e41, 1e46)

# Set y-axis ticks with logarithmic scale
plt.yscale('log')
plt.savefig('other clusters.png')
plt.show()

# %%
# This last graph was just going to be the Mass of the EROSTIA clusters and the mass of the
# GoGreen clusters but I didn't quite get the time to finish it


import numpy as np
import matplotlib.pyplot as plt

data_table = fits_file[1].data

# Extracting data
Mass500 = data_table['M500'] * 10**13
redshift = data_table['BEST_Z']
match_names = data_table["MATCH_NAME"]

# Create a boolean mask to filter rows
mask = np.array(["GOGREEN-GCLASS" in name for name in match_names])

# Plotting M500 vs Redshift for GOGREEN-GCLASS clusters only
plt.figure(figsize=(10, 6))
plt.scatter(redshift[mask], Mass500[mask], color='red', marker='x', s=20, alpha=0.7, label='GOGREEN-GCLASS Clusters')

plt.xlabel('Redshift')
plt.ylabel('M500(10^14 Mass of Sun)')
plt.title('M500 vs. Redshift for GOGREEN-GCLASS Clusters')
plt.grid(True)

# Set y-limits and y-scale
plt.ylim(1e12, 1e16)
plt.yscale('log')

plt.legend()
plt.show()
